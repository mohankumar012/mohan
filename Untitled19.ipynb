# %% [markdown]
# Project Title: Board new dataset Analysis
#
# Purpose
#
#  Determine the purpose of your analysis. What questions are you trying to answer? What insights are you hoping to gain from the data? Having clear objectives will help focus your analysis.
#
#  Step 0:Installing the packages beforehand

# %%
# !pip install pandas
# !pip install matplotlib

# %% [markdown]
# Step 1:import the Necessary packages

# %%
# Importing the necessary packages for data manipulation and visualization

import pandas as pd  # Data Manipulation
import matplotlib.pyplot as plt # Data Visualization

# %% [markdown]
# Step 2:Loading the files from the local system to the Notebook

# %%
# Load the files
data = pd.read_csv("5_6163282317482659489.csv")  #Function to read the csv file from thhe file path
print(data)
# Out:
#     LOCATION       Country         VAR  \
# 0        AUS     Australia  BB-DATA-GB
# 1        AUT       Austria  BB-DATA-GB
# 2        BEL       Belgium  BB-DATA-GB
# 3        DNK       Denmark  BB-DATA-GB
# 4        FIN       Finland  BB-DATA-GB
# ..       ...           ...         ...
# 393      LTU     Lithuania  BB-DATA-GB
# 394      SVN      Slovenia  BB-DATA-GB
# 395     OECD  OECD - Total  BB-DATA-GB
# 396      ISR        Israel  BB-DATA-GB
# 397      CRI    Costa Rica  BB-DATA-GB
#
#                                              Variable   TIME  Time  Unit Code  \
# 0    Mobile data usage per mobile broadband subscri...  2012  2012          0
# 1    Mobile data usage per mobile broadband subscri...  2012  2012          0
# 2    Mobile data usage per mobile broadband subscri...  2012  2012          0
# 3    Mobile data usage per mobile broadband subscri...  2012  2012          0
# 4    Mobile data usage per mobile broadband subscri...  2012  2012          0
# ...

# %% [markdown]
# Step 3:Data View

# %%
data.head()  #print the first 5 rows of the dataset
# Out:
#   LOCATION    Country         VAR  \
# 0      AUS  Australia  BB-DATA-GB
# 1      AUT    Austria  BB-DATA-GB
# 2      BEL    Belgium  BB-DATA-GB
# 3      DNK    Denmark  BB-DATA-GB
# 4      FIN    Finland  BB-DATA-GB
#
#                                            Variable   TIME  Time  Unit Code  \
# 0  Mobile data usage per mobile broadband subscri...  2012  2012          0
# 1  Mobile data usage per mobile broadband subscri...  2012  2012          0
# 2  Mobile data usage per mobile broadband subscri...  2012  2012          0
# 3  Mobile data usage per mobile broadband subscri...  2012  2012          0
# 4  Mobile data usage per mobile broadband subscri...  2012  2012          0
#
#    Unit  PowerCode  PowerCode  Reference   Reference .1    Value
# 0     0           0     Units           0             0  212.000
# 1     0           0     Units           0             0    1.373
# 2     0           0     Units           0             0  115.000
# ...

# %%
# To print the column names present in the dataset
data.columns
# Out:
# Index(['LOCATION', 'Country', 'VAR', 'Variable ', 'TIME', 'Time', 'Unit Code',
#        'Unit', 'PowerCode ', 'PowerCode', 'Reference ', 'Reference .1',
#        'Value'],
#       dtype='object')

# %%
# Gives the a concise summary of a DataFrame.
data.info
# Out:
# <bound method DataFrame.info of     LOCATION       Country         VAR  \
# 0        AUS     Australia  BB-DATA-GB
# 1        AUT       Austria  BB-DATA-GB
# 2        BEL       Belgium  BB-DATA-GB
# 3        DNK       Denmark  BB-DATA-GB
# 4        FIN       Finland  BB-DATA-GB
# ..       ...           ...         ...
# 393      LTU     Lithuania  BB-DATA-GB
# 394      SVN      Slovenia  BB-DATA-GB
# 395     OECD  OECD - Total  BB-DATA-GB
# 396      ISR        Israel  BB-DATA-GB
# 397      CRI    Costa Rica  BB-DATA-GB
#
#                                              Variable   TIME  Time  Unit Code  \
# 0    Mobile data usage per mobile broadband subscri...  2012  2012          0
# 1    Mobile data usage per mobile broadband subscri...  2012  2012          0
# 2    Mobile data usage per mobile broadband subscri...  2012  2012          0
# 3    Mobile data usage per mobile broadband subscri...  2012  2012          0
# ...

# %%
# prints thhe shape i.e., the row size by column size of the dataset
data.shape
# Out:
# (398, 13)

# %%
# Gives the details on the datatype present in each column
data.dtypes
# Out:
# LOCATION         object
# Country          object
# VAR              object
# Variable         object
# TIME              int64
# Time              int64
# Unit Code         int64
# Unit              int64
# PowerCode         int64
# PowerCode        object
# Reference         int64
# Reference .1      int64
# Value           float64
# dtype: object

# %%
#Gives the overall info of the dataframe object
data.describe()
# Out:
#               TIME         Time  Unit Code   Unit  PowerCode   Reference   \
# count   398.000000   398.000000      398.0  398.0       398.0       398.0
# mean   2017.314070  2017.314070        0.0    0.0         0.0         0.0
# std       3.057691     3.057691        0.0    0.0         0.0         0.0
# min    2012.000000  2012.000000        0.0    0.0         0.0         0.0
# 25%    2015.000000  2015.000000        0.0    0.0         0.0         0.0
# 50%    2017.000000  2017.000000        0.0    0.0         0.0         0.0
# 75%    2020.000000  2020.000000        0.0    0.0         0.0         0.0
# max    2022.000000  2022.000000        0.0    0.0         0.0         0.0
#
#        Reference .1       Value
# count         398.0  398.000000
# mean            0.0  106.511563
# std             0.0  244.570338
# min             0.0    0.190000
# 25%             0.0    2.655250
# 50%             0.0    6.004000
# 75%             0.0   15.029000
# max             0.0  976.000000

# %% [markdown]
# Step 4:Data Cleaning(Filteration)

# %%
#Shows the number of rows in a particular column.useful for finding missing values
data.count()
# Out:
# LOCATION        398
# Country         398
# VAR             398
# Variable        398
# TIME            398
# Time            398
# Unit Code       398
# Unit            398
# PowerCode       398
# PowerCode       398
# Reference       398
# Reference .1    398
# Value           398
# dtype: int64

# %%
# To get the values from the dataset
data.value_counts()
# Out:
# LOCATION  Country        VAR         Variable                                                           TIME  Time  Unit Code  Unit  PowerCode   PowerCode  Reference   Reference .1  Value
# AUS       Australia      BB-DATA-GB  Mobile data usage per mobile broadband subscription, GB per month  2012  2012  0          0     0           Units      0           0             212.000    1
# LVA       Latvia         BB-DATA-GB  Mobile data usage per mobile broadband subscription, GB per month  2017  2017  0          0     0           Units      0           0             13.836     1
#                                                                                                         2015  2015  0          0     0           Units      0           0             6.196      1
#                                                                                                         2014  2014  0          0     0           Units      0           0             2.340      1
# ...

# %%
# Give the unique values present in the specific columns
data['Country'].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Denmark', 'Finland', 'France',
#        'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy',
#        'Japan', 'Netherlands', 'Norway', 'Poland', 'Portugal', 'Spain',
#        'Sweden', 'Switzerland', 'United Kingdom', 'United States',
#        'Colombia', 'Estonia', 'Lithuania', 'OECD - Total', 'Luxembourg',
#        'Slovenia', 'Israel', 'Czechia', 'Korea', 'Türkiye', 'Latvia',
#        'Costa Rica', 'Canada', 'Mexico', 'New Zealand', 'Slovak Republic',
#        'Chile'], dtype=object)

# %%
# To remove all null values present in the Dataset
data.dropna()
# Out:
#     LOCATION       Country         VAR  \
# 0        AUS     Australia  BB-DATA-GB
# 1        AUT       Austria  BB-DATA-GB
# 2        BEL       Belgium  BB-DATA-GB
# 3        DNK       Denmark  BB-DATA-GB
# 4        FIN       Finland  BB-DATA-GB
# ..       ...           ...         ...
# 393      LTU     Lithuania  BB-DATA-GB
# 394      SVN      Slovenia  BB-DATA-GB
# 395     OECD  OECD - Total  BB-DATA-GB
# 396      ISR        Israel  BB-DATA-GB
# 397      CRI    Costa Rica  BB-DATA-GB
#
#                                              Variable   TIME  Time  Unit Code  \
# 0    Mobile data usage per mobile broadband subscri...  2012  2012          0
# 1    Mobile data usage per mobile broadband subscri...  2012  2012          0
# 2    Mobile data usage per mobile broadband subscri...  2012  2012          0
# 3    Mobile data usage per mobile broadband subscri...  2012  2012          0
# 4    Mobile data usage per mobile broadband subscri...  2012  2012          0
# ...

# %%
# Replaces all instances of null values withh the Boolean value 'True'.
data.dropna(inplace=True)

# %%
#To check if there were any null values that were dropped leading to a change in the shape of the Dataframe object.
data.shape
# Out:
# (398, 13)

# %%
# Prints if the values in the specified
data['Country'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 393     True
# 394     True
# 395     True
# 396     True
# 397     True
# Name: Country, Length: 398, dtype: bool

# %%
duplicate_rows = data.duplicated()
print(duplicate_rows.sum())
# Out:
# 0

# %% [markdown]
# Step 5: Sorting/Searching/Validation

# %%
# Sorting process
# print the target column

print(data['Value'])
# Out:
# 0      212.000
# 1        1.373
# 2      115.000
# 3      692.000
# 4        2.006
#         ...
# 393     27.757
# 394     13.399
# 395     10.359
# 396     11.317
# 397      5.714
# Name: Value, Length: 398, dtype: float64

# %%
# Generate a pie chart to visualize the distribution of the value in the country column


df['Country'].value_counts().plot(kind='pie',autopct='%1.1f%%')

# Add a title to the pie chart indicating the variables being visualized

plt.title("Country")

#Display the pie chart
plt.show()
